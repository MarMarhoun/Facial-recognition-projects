# %% [markdown]
# # Gender classification using Convolutional Neural Network (ConvNet)

# %% [markdown]
# ###### import the Zip file from Google drive
#
# importing zip file in google Colaboratory stored in google drive can be done by two methods:
#
# 1) The first one:
#
# Open the link in a new tab-> you will get a code - copy that back into the prompt you now have access to google drive check:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Then unzip your file using the following command:

# %%
# !unzip "/content/gdrive/MyDrive/FaceApp_NN/model.zip"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: model/data/train/male/male_002006.jpg
#   inflating: model/data/train/male/male_002007.jpg
#   inflating: model/data/train/male/male_002008.jpg
#   inflating: model/data/train/male/male_002009.jpg
#   inflating: model/data/train/male/male_002010.jpg
#   inflating: model/data/train/male/male_002011.jpg
#   inflating: model/data/train/male/male_002012.jpg
#   inflating: model/data/train/male/male_002013.jpg
#   inflating: model/data/train/male/male_002014.jpg
#   inflating: model/data/train/male/male_002015.jpg
#   inflating: model/data/train/male/male_002016.jpg
#   inflating: model/data/train/male/male_002017.jpg
#   inflating: model/data/train/male/male_002018.jpg
#   inflating: model/data/train/male/male_002019.jpg
#   inflating: model/data/train/male/male_002020.jpg
#   inflating: model/data/train/male/male_002021.jpg
#   inflating: model/data/train/male/male_002022.jpg
#   inflating: model/data/train/male/male_002023.jpg
#   inflating: model/data/train/male/male_002024.jpg
#   inflating: model/data/train/male/male_002025.jpg
#   inflating: model/data/train/male/male_002026.jpg
#   inflating: model/data/train/male/male_002027.jpg
#   inflating: model/data/train/male/male_002028.jpg
#   inflating: model/data/train/male/male_002029.jpg
#   inflating: model/data/train/male/male_002030.jpg
#   inflating: model/data/train/male/male_002031.jpg
#   inflating: model/data/train/male/male_002032.jpg
#   inflating: model/data/train/male/male_002033.jpg
#   inflating: model/data/train/male/male_002034.jpg
#   inflating: model/data/train/male/male_002035.jpg
#   inflating: model/data/train/male/male_002036.jpg
#   inflating: model/data/train/male/male_002037.jpg
#   inflating: model/data/train/male/male_002038.jpg
#   inflating: model/data/train/male/male_002039.jpg
#   inflating: model/data/train/male/male_002040.jpg
#   inflating: model/data/train/male/male_002041.jpg
#   inflating: model/data/train/male/male_002042.jpg
#   inflating: model/data/train/male/male_002043.jpg
#   inflating: model/data/train/male/male_002044.jpg
#   inflating: model/data/train/male/male_002045.jpg
#   inflating: model/data/train/male/male_002046.jpg
#   inflating: model/data/train/male/male_002047.jpg
#   inflating: model/data/train/male/male_002048.jpg
#   inflating: model/data/train/male/male_002049.jpg
#   inflating: model/data/train/male/male_002050.jpg
#   inflating: model/data/train/male/male_002051.jpg
#   inflating: model/data/train/male/male_002052.jpg
#   inflating: model/data/train/male/male_002053.jpg
#   inflating: model/data/train/male/male_002054.jpg
#   inflating: model/data/train/male/male_002055.jpg
#   inflating: model/data/train/male/male_002056.jpg
#   inflating: model/data/train/male/male_002057.jpg
#   inflating: model/data/train/male/male_002058.jpg
#   inflating: model/data/train/male/male_002059.jpg
#   inflating: model/data/train/male/male_002060.jpg
#   inflating: model/data/train/male/male_002061.jpg
#   inflating: model/data/train/male/male_002062.jpg
#   inflating: model/data/train/male/male_002063.jpg
#   inflating: model/data/train/male/male_002064.jpg
#   inflating: model/data/train/male/male_002065.jpg
#   inflating: model/data/train/male/male_002066.jpg
#   inflating: model/data/train/male/male_002067.jpg
#   inflating: model/data/train/male/male_002068.jpg
#   inflating: model/data/train/male/male_002069.jpg
#   inflating: model/data/train/male/male_002070.jpg
#   inflating: model/data/train/male/male_002071.jpg
#   inflating: model/data/train/male/male_002072.jpg
#   inflating: model/data/train/male/male_002073.jpg
#   inflating: model/data/train/male/male_002074.jpg
#   inflating: model/data/train/male/male_002075.jpg
#   inflating: model/data/train/male/male_002076.jpg
#   inflating: model/data/train/male/male_002077.jpg
#   inflating: model/data/train/male/male_002078.jpg
#   inflating: model/data/train/male/male_002079.jpg
#   inflating: model/data/train/male/male_002080.jpg
#   inflating: model/data/train/male/male_002081.jpg
#   inflating: model/data/train/male/male_002082.jpg
#   inflating: model/data/train/male/male_002083.jpg
#   inflating: model/data/train/male/male_002084.jpg
#   inflating: model/data/train/male/male_002085.jpg
#   inflating: model/data/train/male/male_002086.jpg
#   inflating: model/data/train/male/male_002087.jpg
#   inflating: model/data/train/male/male_002088.jpg
#   inflating: model/data/train/male/male_002089.jpg
#   inflating: model/data/train/male/male_002090.jpg
#   inflating: model/data/train/male/male_002091.jpg
#   inflating: model/data/train/male/male_002092.jpg
#   inflating: model/data/train/male/male_002093.jpg
#   inflating: model/data/train/male/male_002094.jpg
#   inflating: model/data/train/male/male_002095.jpg
#   inflating: model/data/train/male/male_002096.jpg
#   inflating: model/data/train/male/male_002097.jpg
#   inflating: model/data/train/male/male_002098.jpg
#   inflating: model/data/train/male/male_002099.jpg
#   inflating: model/data/train/male/male_002100.jpg
#   inflating: model/data/train/male/male_002101.jpg
#   inflating: model/data/train/male/male_002102.jpg
#   inflating: model/data/train/male/male_002103.jpg
#   inflating: model/data/train/male/male_002104.jpg
#   inflating: model/data/train/male/male_002105.jpg
#   inflating: model/data/train/male/male_002106.jpg
#   inflating: model/data/train/male/male_002107.jpg
#   inflating: model/data/train/male/male_002108.jpg
#   inflating: model/data/train/male/male_002109.jpg
#   inflating: model/data/train/male/male_002110.jpg
#   inflating: model/data/train/male/male_002111.jpg
#   inflating: model/data/train/male/male_002112.jpg
#   inflating: model/data/train/male/male_002113.jpg
#   inflating: model/data/train/male/male_002114.jpg
#   inflating: model/data/train/male/male_002115.jpg
#   inflating: model/data/train/male/male_002116.jpg
#   inflating: model/data/train/male/male_002117.jpg
#   inflating: model/data/train/male/male_002118.jpg
#   inflating: model/data/train/male/male_002119.jpg
#   inflating: model/data/train/male/male_002120.jpg
#   inflating: model/data/train/male/male_002121.jpg
#   inflating: model/data/train/male/male_002122.jpg
#   inflating: model/data/train/male/male_002123.jpg
#   inflating: model/data/train/male/male_002124.jpg
#   inflating: model/data/train/male/male_002125.jpg
#   inflating: model/data/train/male/male_002126.jpg
#   inflating: model/data/train/male/male_002127.jpg
#   inflating: model/data/train/male/male_002128.jpg
#   inflating: model/data/train/male/male_002129.jpg
#   inflating: model/data/train/male/male_002130.jpg
#   inflating: model/data/train/male/male_002131.jpg
#   inflating: model/data/train/male/male_002132.jpg
#   inflating: model/data/train/male/male_002133.jpg
#   inflating: model/data/train/male/male_002134.jpg
#   inflating: model/data/train/male/male_002135.jpg
#   inflating: model/data/train/male/male_002136.jpg
#   inflating: model/data/train/male/male_002137.jpg
#   inflating: model/data/train/male/male_002138.jpg
#   inflating: model/data/train/male/male_002139.jpg
#   inflating: model/data/train/male/male_002140.jpg
#   inflating: model/data/train/male/male_002141.jpg
#   inflating: model/data/train/male/male_002142.jpg
#   inflating: model/data/train/male/male_002143.jpg
#   inflating: model/data/train/male/male_002144.jpg
#   inflating: model/data/train/male/male_002145.jpg
#   inflating: model/data/train/male/male_002146.jpg
#   inflating: model/data/train/male/male_002147.jpg
#   inflating: model/data/train/male/male_002148.jpg
#   inflating: model/data/train/male/male_002149.jpg
#   inflating: model/data/train/male/male_002150.jpg
#   inflating: model/data/train/male/male_002151.jpg
#   inflating: model/data/train/male/male_002152.jpg
#   inflating: model/data/train/male/male_002153.jpg
#   inflating: model/data/train/male/male_002154.jpg
#   inflating: model/data/train/male/male_002155.jpg
#   inflating: model/data/train/male/male_002156.jpg
#   inflating: model/data/train/male/male_002157.jpg
#   inflating: model/data/train/male/male_002158.jpg
#   inflating: model/data/train/male/male_002159.jpg
#   inflating: model/data/train/male/male_002160.jpg
#   inflating: model/data/train/male/male_002161.jpg
#   inflating: model/data/train/male/male_002162.jpg
#   inflating: model/data/train/male/male_002163.jpg
#   inflating: model/data/train/male/male_002164.jpg
#   inflating: model/data/train/male/male_002165.jpg
#   inflating: model/data/train/male/male_002166.jpg
#   inflating: model/data/train/male/male_002167.jpg
#   inflating: model/data/train/male/male_002168.jpg
#   inflating: model/data/train/male/male_002169.jpg
#   inflating: model/data/train/male/male_002170.jpg
#   inflating: model/data/train/male/male_002171.jpg
#   inflating: model/data/train/male/male_002172.jpg
#   inflating: model/data/train/male/male_002173.jpg
#   inflating: model/data/train/male/male_002174.jpg
#   inflating: model/data/train/male/male_002175.jpg
#   inflating: model/data/train/male/male_002176.jpg
#   inflating: model/data/train/male/male_002177.jpg
#   inflating: model/data/train/male/male_002178.jpg
#   inflating: model/data/train/male/male_002179.jpg
#   inflating: model/data/train/male/male_002180.jpg
#   inflating: model/data/train/male/male_002181.jpg
#   inflating: model/data/train/male/male_002182.jpg
#   inflating: model/data/train/male/male_002183.jpg
#   inflating: model/data/train/male/male_002184.jpg
#   inflating: model/data/train/male/male_002185.jpg
#   inflating: model/data/train/male/male_002186.jpg
#   inflating: model/data/train/male/male_002187.jpg
#   inflating: model/data/train/male/male_002188.jpg
#   inflating: model/data/train/male/male_002189.jpg
#   inflating: model/data/train/male/male_002190.jpg
#   inflating: model/data/train/male/male_002191.jpg
#   inflating: model/data/train/male/male_002192.jpg
#   inflating: model/data/train/male/male_002193.jpg
#   inflating: model/data/train/male/male_002194.jpg
#   inflating: model/data/train/male/male_002195.jpg
#   inflating: model/data/train/male/male_002196.jpg
#   inflating: model/data/train/male/male_002197.jpg
#   inflating: model/data/train/male/male_002198.jpg
#   inflating: model/data/train/male/male_002199.jpg
#   inflating: model/data/train/male/male_002200.jpg
#   inflating: model/data/train/male/male_002201.jpg
#   inflating: model/data/train/male/male_002202.jpg
#   inflating: model/data/train/male/male_002203.jpg
#   inflating: model/data/train/male/male_002204.jpg
#   inflating: model/data/train/male/male_002205.jpg
#   inflating: model/data/train/male/male_002206.jpg
#   inflating: model/data/train/male/male_002207.jpg
#   inflating: model/data/train/male/male_002208.jpg
#   inflating: model/data/train/male/male_002209.jpg
#   inflating: model/data/train/male/male_002210.jpg
#   inflating: model/data/train/male/male_002211.jpg
#   inflating: model/data/train/male/male_002212.jpg
#   inflating: model/data/train/male/male_002213.jpg
#   inflating: model/data/train/male/male_002214.jpg
#   inflating: model/data/train/male/male_002215.jpg
#   inflating: model/data/train/male/male_002216.jpg
#   inflating: model/data/train/male/male_002217.jpg
#   inflating: model/data/train/male/male_002218.jpg
#   inflating: model/data/train/male/male_002219.jpg
#   inflating: model/data/train/male/male_002220.jpg
#   inflating: model/data/train/male/male_002221.jpg
#   inflating: model/data/train/male/male_002222.jpg
#   inflating: model/data/train/male/male_002223.jpg
#   inflating: model/data/train/male/male_002224.jpg
#   inflating: model/data/train/male/male_002225.jpg
#   inflating: model/data/train/male/male_002226.jpg
#   inflating: model/data/train/male/male_002227.jpg
#   inflating: model/data/train/male/male_002228.jpg
#   inflating: model/data/train/male/male_002229.jpg
#   inflating: model/data/train/male/male_002230.jpg
#   inflating: model/data/train/male/male_002231.jpg
#   inflating: model/data/train/male/male_002232.jpg
#   inflating: model/data/train/male/male_002233.jpg
#   inflating: model/data/train/male/male_002234.jpg
#   inflating: model/data/train/male/male_002235.jpg
#   inflating: model/data/train/male/male_002236.jpg
#   inflating: model/data/train/male/male_002237.jpg
#   inflating: model/data/train/male/male_002238.jpg
#   inflating: model/data/train/male/male_002239.jpg
#   inflating: model/data/train/male/male_002240.jpg
#   inflating: model/data/train/male/male_002241.jpg
#   inflating: model/data/train/male/male_002242.jpg
#   inflating: model/data/train/male/male_002243.jpg
#   inflating: model/data/train/male/male_002244.jpg
#   inflating: model/data/train/male/male_002245.jpg
#   inflating: model/data/train/male/male_002246.jpg
#   inflating: model/data/train/male/male_002247.jpg
#   inflating: model/data/train/male/male_002248.jpg
#   inflating: model/data/train/male/male_002249.jpg
#   inflating: model/data/train/male/male_002250.jpg
#   inflating: model/data/train/male/male_002251.jpg
#   inflating: model/data/train/male/male_002252.jpg
#   inflating: model/data/train/male/male_002253.jpg
#   inflating: model/data/train/male/male_002254.jpg
#   inflating: model/data/train/male/male_002255.jpg
#   inflating: model/data/train/male/male_002256.jpg
#   inflating: model/data/train/male/male_002257.jpg
#   inflating: model/data/train/male/male_002258.jpg
#   inflating: model/data/train/male/male_002259.jpg
#   inflating: model/data/train/male/male_002260.jpg
#   inflating: model/data/train/male/male_002261.jpg
#   inflating: model/data/train/male/male_002262.jpg
#   inflating: model/data/train/male/male_002263.jpg
#   inflating: model/data/train/male/male_002264.jpg
#   inflating: model/data/train/male/male_002265.jpg
#   inflating: model/data/train/male/male_002266.jpg
#   inflating: model/data/train/male/male_002267.jpg
#   inflating: model/data/train/male/male_002268.jpg
#   inflating: model/data/train/male/male_002269.jpg
#   inflating: model/data/train/male/male_002270.jpg
#   inflating: model/data/train/male/male_002271.jpg
#   inflating: model/data/train/male/male_002272.jpg
#   inflating: model/data/train/male/male_002273.jpg
#   inflating: model/data/train/male/male_002274.jpg
#   inflating: model/data/train/male/male_002275.jpg
#   inflating: model/data/train/male/male_002276.jpg
#   inflating: model/data/train/male/male_002277.jpg
#   inflating: model/data/train/male/male_002278.jpg
#   inflating: model/data/train/male/male_002279.jpg
#   inflating: model/data/train/male/male_002280.jpg
#   inflating: model/data/train/male/male_002281.jpg
#   inflating: model/data/train/male/male_002282.jpg
#   inflating: model/data/train/male/male_002283.jpg
#   inflating: model/data/train/male/male_002284.jpg
#   inflating: model/data/train/male/male_002285.jpg
#   inflating: model/data/train/male/male_002286.jpg
#   inflating: model/data/train/male/male_002287.jpg
#   inflating: model/data/train/male/male_002288.jpg
#   inflating: model/data/train/male/male_002289.jpg
#   inflating: model/data/train/male/male_002290.jpg
#   inflating: model/data/train/male/male_002291.jpg
#   inflating: model/data/train/male/male_002292.jpg
#   inflating: model/data/train/male/male_002293.jpg
#   inflating: model/data/train/male/male_002294.jpg
#   inflating: model/data/train/male/male_002295.jpg
#   inflating: model/data/train/male/male_002296.jpg
#   inflating: model/data/train/male/male_002297.jpg
#   inflating: model/data/train/male/male_002298.jpg
#   inflating: model/data/train/male/male_002299.jpg
#   inflating: model/data/train/male/male_002300.jpg
#   inflating: model/data/train/male/male_002301.jpg
#   inflating: model/data/train/male/male_002302.jpg
#   inflating: model/data/train/male/male_002303.jpg
#   inflating: model/data/train/male/male_002304.jpg
#   inflating: model/data/train/male/male_002305.jpg
#   inflating: model/data/train/male/male_002306.jpg
#   inflating: model/data/train/male/male_002307.jpg
#   inflating: model/data/train/male/male_002308.jpg
#   inflating: model/data/train/male/male_002309.jpg
#   inflating: model/data/train/male/male_002310.jpg
#   inflating: model/data/train/male/male_002311.jpg
#   inflating: model/data/train/male/male_002312.jpg
#   inflating: model/data/train/male/male_002313.jpg
#   inflating: model/data/train/male/male_002314.jpg
#   inflating: model/data/train/male/male_002315.jpg
#   inflating: model/data/train/male/male_002316.jpg
#   inflating: model/data/train/male/male_002317.jpg
#   inflating: model/data/train/male/male_002318.jpg
#   inflating: model/data/train/male/male_002319.jpg
#   inflating: model/data/train/male/male_002320.jpg
#   inflating: model/data/train/male/male_002321.jpg
#   inflating: model/data/train/male/male_002322.jpg
#   inflating: model/data/train/male/male_002323.jpg
#   inflating: model/data/train/male/male_002324.jpg
#   inflating: model/data/train/male/male_002325.jpg
#   inflating: model/data/train/male/male_002326.jpg
#   inflating: model/data/train/male/male_002327.jpg
#   inflating: model/data/train/male/male_002328.jpg
#   inflating: model/data/train/male/male_002329.jpg
#   inflating: model/data/train/male/male_002330.jpg
#   inflating: model/data/train/male/male_002331.jpg
#   inflating: model/data/train/male/male_002332.jpg
#   inflating: model/data/train/male/male_002333.jpg
#   inflating: model/data/train/male/male_002334.jpg
#   inflating: model/data/train/male/male_002335.jpg
#   inflating: model/data/train/male/male_002336.jpg
#   inflating: model/data/train/male/male_002337.jpg
#   inflating: model/data/train/male/male_002338.jpg
#   inflating: model/data/train/male/male_002339.jpg
#   inflating: model/data/train/male/male_002340.jpg
#   inflating: model/data/train/male/male_002341.jpg
#   inflating: model/data/train/male/male_002342.jpg
#   inflating: model/data/train/male/male_002343.jpg
#   inflating: model/data/train/male/male_002344.jpg
#   inflating: model/data/train/male/male_002345.jpg
#   inflating: model/data/train/male/male_002346.jpg
#   inflating: model/data/train/male/male_002347.jpg
#   inflating: model/data/train/male/male_002348.jpg
#   inflating: model/data/train/male/male_002349.jpg
#   inflating: model/data/train/male/male_002350.jpg
#   inflating: model/data/train/male/male_002351.jpg
#   inflating: model/data/train/male/male_002352.jpg
#   inflating: model/data/train/male/male_002353.jpg
#   inflating: model/data/train/male/male_002354.jpg
#   inflating: model/data/train/male/male_002355.jpg
#   inflating: model/data/train/male/male_002356.jpg
#   inflating: model/data/train/male/male_002357.jpg
#   inflating: model/data/train/male/male_002358.jpg
#   inflating: model/data/train/male/male_002359.jpg
#   inflating: model/data/train/male/male_002360.jpg
#   inflating: model/data/train/male/male_002361.jpg
#   inflating: model/data/train/male/male_002362.jpg
#   inflating: model/data/train/male/male_002363.jpg
#   inflating: model/data/train/male/male_002364.jpg
#   inflating: model/data/train/male/male_002365.jpg
#   inflating: model/data/train/male/male_002366.jpg
#   inflating: model/data/train/male/male_002367.jpg
#   inflating: model/data/train/male/male_002368.jpg
#   inflating: model/data/train/male/male_002369.jpg
#   inflating: model/data/train/male/male_002370.jpg
#   inflating: model/data/train/male/male_002371.jpg
#   inflating: model/data/train/male/male_002372.jpg
#   inflating: model/data/train/male/male_002373.jpg
#   inflating: model/data/train/male/male_002374.jpg
#   inflating: model/data/train/male/male_002375.jpg
#   inflating: model/data/train/male/male_002376.jpg
#   inflating: model/data/train/male/male_002377.jpg
#   inflating: model/data/train/male/male_002378.jpg
#   inflating: model/data/train/male/male_002379.jpg
#   inflating: model/data/train/male/male_002380.jpg
#   inflating: model/data/train/male/male_002381.jpg
#   inflating: model/data/train/male/male_002382.jpg
#   inflating: model/data/train/male/male_002383.jpg
#   inflating: model/data/train/male/male_002384.jpg
#   inflating: model/data/train/male/male_002385.jpg
#   inflating: model/data/train/male/male_002386.jpg
#   inflating: model/data/train/male/male_002387.jpg
#   inflating: model/data/train/male/male_002388.jpg
#   inflating: model/data/train/male/male_002389.jpg
#   inflating: model/data/train/male/male_002390.jpg
#   inflating: model/data/train/male/male_002391.jpg
#   inflating: model/data/train/male/male_002392.jpg
#   inflating: model/data/train/male/male_002393.jpg
#   inflating: model/data/train/male/male_002394.jpg
#   inflating: model/data/train/male/male_002395.jpg
#   inflating: model/data/train/male/male_002396.jpg
#   inflating: model/data/train/male/male_002397.jpg
#   inflating: model/data/train/male/male_002398.jpg
#   inflating: model/data/train/male/male_002399.jpg
#   inflating: model/data/train/male/male_002400.jpg
#   inflating: model/data/train/male/male_002401.jpg
#   inflating: model/data/train/male/male_002402.jpg
#   inflating: model/data/train/male/male_002403.jpg
#   inflating: model/data/train/male/male_002404.jpg
#   inflating: model/data/train/male/male_002405.jpg
#   inflating: model/data/train/male/male_002406.jpg
#   inflating: model/data/train/male/male_002407.jpg
#   inflating: model/data/train/male/male_002408.jpg
#   inflating: model/data/train/male/male_002409.jpg
#   inflating: model/data/train/male/male_002410.jpg
#   inflating: model/data/train/male/male_002411.jpg
#   inflating: model/data/train/male/male_002412.jpg
#   inflating: model/data/train/male/male_002413.jpg
#   inflating: model/data/train/male/male_002414.jpg
#   inflating: model/data/train/male/male_002415.jpg
#   inflating: model/data/train/male/male_002416.jpg
#   inflating: model/data/train/male/male_002417.jpg
#   inflating: model/data/train/male/male_002418.jpg
#   inflating: model/data/train/male/male_002419.jpg
#   inflating: model/data/train/male/male_002420.jpg
#   inflating: model/data/train/male/male_002421.jpg
#   inflating: model/data/train/male/male_002422.jpg
#   inflating: model/data/train/male/male_002423.jpg
#   inflating: model/data/train/male/male_002424.jpg
#   inflating: model/data/train/male/male_002425.jpg
#   inflating: model/data/train/male/male_002426.jpg
#   inflating: model/data/train/male/male_002427.jpg
#   inflating: model/data/train/male/male_002428.jpg
#   inflating: model/data/train/male/male_002429.jpg
#   inflating: model/data/train/male/male_002430.jpg
#   inflating: model/data/train/male/male_002431.jpg
#   inflating: model/data/train/male/male_002432.jpg
#   inflating: model/data/train/male/male_002433.jpg
#   inflating: model/data/train/male/male_002434.jpg
#   inflating: model/data/train/male/male_002435.jpg
#   inflating: model/data/train/male/male_002436.jpg
#   inflating: model/data/train/male/male_002437.jpg
#   inflating: model/data/train/male/male_002438.jpg
#   inflating: model/data/train/male/male_002439.jpg
#   inflating: model/data/train/male/male_002440.jpg
#   inflating: model/data/train/male/male_002441.jpg
#   inflating: model/data/train/male/male_002442.jpg
#   inflating: model/data/train/male/male_002443.jpg
#   inflating: model/data/train/male/male_002444.jpg
#   inflating: model/data/train/male/male_002445.jpg
#   inflating: model/data/train/male/male_002446.jpg
#   inflating: model/data/train/male/male_002447.jpg
#   inflating: model/data/train/male/male_002448.jpg
#   inflating: model/data/train/male/male_002449.jpg
#   inflating: model/data/train/male/male_002450.jpg
#   inflating: model/data/train/male/male_002451.jpg
#   inflating: model/data/train/male/male_002452.jpg
#   inflating: model/data/train/male/male_002453.jpg
#   inflating: model/data/train/male/male_002454.jpg
#   inflating: model/data/train/male/male_002455.jpg
#   inflating: model/data/train/male/male_002456.jpg
#   inflating: model/data/train/male/male_002457.jpg
#   inflating: model/data/train/male/male_002458.jpg
#   inflating: model/data/train/male/male_002459.jpg
#   inflating: model/data/train/male/male_002460.jpg
#   inflating: model/data/train/male/male_002461.jpg
#   inflating: model/data/train/male/male_002462.jpg
#   inflating: model/data/train/male/male_002463.jpg
#   inflating: model/data/train/male/male_002464.jpg
#   inflating: model/data/train/male/male_002465.jpg
#   inflating: model/data/train/male/male_002466.jpg
#   inflating: model/data/train/male/male_002467.jpg
#   inflating: model/data/train/male/male_002468.jpg
#   inflating: model/data/train/male/male_002469.jpg
#   inflating: model/data/train/male/male_002470.jpg
#   inflating: model/data/train/male/male_002471.jpg
#   inflating: model/data/train/male/male_002472.jpg
#   inflating: model/data/train/male/male_002473.jpg
#   inflating: model/data/train/male/male_002474.jpg
#   inflating: model/data/train/male/male_002475.jpg
#   inflating: model/data/train/male/male_002476.jpg
#   inflating: model/data/train/male/male_002477.jpg
#   inflating: model/data/train/male/male_002478.jpg
#   inflating: model/data/train/male/male_002479.jpg
#   inflating: model/data/train/male/male_002480.jpg
#   inflating: model/data/train/male/male_002481.jpg
#   inflating: model/data/train/male/male_002482.jpg
#   inflating: model/data/train/male/male_002483.jpg
#   inflating: model/data/train/male/male_002484.jpg
#   inflating: model/data/train/male/male_002485.jpg
#   inflating: model/data/train/male/male_002486.jpg
#   inflating: model/data/train/male/male_002487.jpg
#   inflating: model/data/train/male/male_002488.jpg
#   inflating: model/data/train/male/male_002489.jpg
#   inflating: model/data/train/male/male_002490.jpg
#   inflating: model/data/train/male/male_002491.jpg
#   inflating: model/data/train/male/male_002492.jpg
#   inflating: model/data/train/male/male_002493.jpg
#   inflating: model/data/train/male/male_002494.jpg
#   inflating: model/data/train/male/male_002495.jpg
#   inflating: model/data/train/male/male_002496.jpg
#   inflating: model/data/train/male/male_002497.jpg
#   inflating: model/data/train/male/male_002498.jpg
#   inflating: model/data/train/male/male_002499.jpg
#   inflating: model/data/train/male/male_002500.jpg
#   inflating: model/data/train/male/male_002501.jpg
#   inflating: model/data/train/male/male_002502.jpg
#   inflating: model/data/train/male/male_002503.jpg
#   inflating: model/data/train/male/male_002504.jpg
#   inflating: model/data/train/male/male_002505.jpg
#   inflating: model/data/train/male/male_002506.jpg
#   inflating: model/data/train/male/male_002507.jpg
#   inflating: model/data/train/male/male_002508.jpg
#   inflating: model/data/train/male/male_002509.jpg
#   inflating: model/data/train/male/male_002510.jpg
#   inflating: model/data/train/male/male_002511.jpg
#   inflating: model/data/train/male/male_002512.jpg
#   inflating: model/data/train/male/male_002513.jpg
#   inflating: model/data/train/male/male_002514.jpg
#   inflating: model/data/train/male/male_002515.jpg
#   inflating: model/data/train/male/male_002516.jpg
#   inflating: model/data/train/male/male_002517.jpg
#   inflating: model/data/train/male/male_002518.jpg
#   inflating: model/data/train/male/male_002519.jpg
#   inflating: model/data/train/male/male_002520.jpg
#   inflating: model/data/train/male/male_002521.jpg
#   inflating: model/data/train/male/male_002522.jpg
#   inflating: model/data/train/male/male_002523.jpg
#   inflating: model/data/train/male/male_002524.jpg
#   inflating: model/data/train/male/male_002525.jpg
#   inflating: model/data/train/male/male_002526.jpg
#   inflating: model/data/train/male/male_002527.jpg
#   inflating: model/data/train/male/male_002528.jpg
#   inflating: model/data/train/male/male_002529.jpg
#   inflating: model/data/train/male/male_002530.jpg
#   inflating: model/data/train/male/male_002531.jpg
#   inflating: model/data/train/male/male_002532.jpg
#   inflating: model/data/train/male/male_002533.jpg
#   inflating: model/data/train/male/male_002534.jpg
#   inflating: model/data/train/male/male_002535.jpg
#   inflating: model/data/train/male/male_002536.jpg
#   inflating: model/data/train/male/male_002537.jpg
#   inflating: model/data/train/male/male_002538.jpg
#   inflating: model/data/train/male/male_002539.jpg
#   inflating: model/data/train/male/male_002540.jpg
#   inflating: model/data/train/male/male_002541.jpg
#   inflating: model/data/train/male/male_002542.jpg
#   inflating: model/data/train/male/male_002543.jpg
#   inflating: model/data/train/male/male_002544.jpg
#   inflating: model/data/train/male/male_002545.jpg
#   inflating: model/data/train/male/male_002546.jpg
#   inflating: model/data/train/male/male_002547.jpg
#   inflating: model/data/train/male/male_002548.jpg
#   inflating: model/data/train/male/male_002549.jpg
#   inflating: model/data/train/male/male_002550.jpg
#   inflating: model/data/train/male/male_002551.jpg
#   inflating: model/data/train/male/male_002552.jpg
#   inflating: model/data/train/male/male_002553.jpg
#   inflating: model/data/train/male/male_002554.jpg
#   inflating: model/data/train/male/male_002555.jpg
#   inflating: model/data/train/male/male_002556.jpg
#   inflating: model/data/train/male/male_002557.jpg
#   inflating: model/data/train/male/male_002558.jpg
#   inflating: model/data/train/male/male_002559.jpg
#   inflating: model/data/train/male/male_002560.jpg
#   inflating: model/data/train/male/male_002561.jpg
#   inflating: model/data/train/male/male_002562.jpg
#   inflating: model/data/train/male/male_002563.jpg
#   inflating: model/data/train/male/male_002564.jpg
#   inflating: model/data/train/male/male_002565.jpg
#   inflating: model/data/train/male/male_002566.jpg
#   inflating: model/data/train/male/male_002567.jpg
#   inflating: model/data/train/male/male_002568.jpg
#   inflating: model/data/train/male/male_002569.jpg
#   inflating: model/data/train/male/male_002570.jpg
#   inflating: model/data/train/male/male_002571.jpg
#   inflating: model/data/train/male/male_002572.jpg
#   inflating: model/data/train/male/male_002573.jpg
#   inflating: model/data/train/male/male_002574.jpg
#   inflating: model/data/train/male/male_002575.jpg
#   inflating: model/data/train/male/male_002576.jpg
#   inflating: model/data/train/male/male_002577.jpg
#   inflating: model/data/train/male/male_002578.jpg
#   inflating: model/data/train/male/male_002579.jpg
#   inflating: model/data/train/male/male_002580.jpg
#   inflating: model/data/train/male/male_002581.jpg
#   inflating: model/data/train/male/male_002582.jpg
#   inflating: model/data/train/male/male_002583.jpg
#   inflating: model/data/train/male/male_002584.jpg
#   inflating: model/data/train/male/male_002585.jpg
#   inflating: model/data/train/male/male_002586.jpg
#   inflating: model/data/train/male/male_002587.jpg
#   inflating: model/data/train/male/male_002588.jpg
#   inflating: model/data/train/male/male_002589.jpg
#   inflating: model/data/train/male/male_002590.jpg
#   inflating: model/data/train/male/male_002591.jpg
#   inflating: model/data/train/male/male_002592.jpg
#   inflating: model/data/train/male/male_002593.jpg
#   inflating: model/data/train/male/male_002594.jpg
#   inflating: model/data/train/male/male_002595.jpg
#   inflating: model/data/train/male/male_002596.jpg
#   inflating: model/data/train/male/male_002597.jpg
#   inflating: model/data/train/male/male_002598.jpg
#   inflating: model/data/train/male/male_002599.jpg
#   inflating: model/data/train/male/male_002600.jpg
#   inflating: model/data/train/male/male_002601.jpg
#   inflating: model/data/train/male/male_002602.jpg
#   inflating: model/data/train/male/male_002603.jpg
#   inflating: model/data/train/male/male_002604.jpg
#   inflating: model/data/train/male/male_002605.jpg
#   inflating: model/data/train/male/male_002606.jpg
#   inflating: model/data/train/male/male_002607.jpg
#   inflating: model/data/train/male/male_002608.jpg
#   inflating: model/data/train/male/male_002609.jpg
#   inflating: model/data/train/male/male_002610.jpg
#   inflating: model/data/train/male/male_002611.jpg
#   inflating: model/data/train/male/male_002612.jpg
#   inflating: model/data/train/male/male_002613.jpg
#   inflating: model/data/train/male/male_002614.jpg
#   inflating: model/data/train/male/male_002615.jpg
#   inflating: model/data/train/male/male_002616.jpg
#   inflating: model/data/train/male/male_002617.jpg
#   inflating: model/data/train/male/male_002618.jpg
#   inflating: model/data/train/male/male_002619.jpg
#   inflating: model/data/train/male/male_002620.jpg
#   inflating: model/data/train/male/male_002621.jpg
#   inflating: model/data/train/male/male_002622.jpg
#   inflating: model/data/train/male/male_002623.jpg
#   inflating: model/data/train/male/male_002624.jpg
#   inflating: model/data/train/male/male_002625.jpg
#   inflating: model/data/train/male/male_002626.jpg
#   inflating: model/data/train/male/male_002627.jpg
#   inflating: model/data/train/male/male_002628.jpg
#   inflating: model/data/train/male/male_002629.jpg
#   inflating: model/data/train/male/male_002630.jpg
#   inflating: model/data/train/male/male_002631.jpg
#   inflating: model/data/train/male/male_002632.jpg
#   inflating: model/data/train/male/male_002633.jpg
#   inflating: model/data/train/male/male_002634.jpg
#   inflating: model/data/train/male/male_002635.jpg
#   inflating: model/data/train/male/male_002636.jpg
#   inflating: model/data/train/male/male_002637.jpg
#   inflating: model/data/train/male/male_002638.jpg
#   inflating: model/data/train/male/male_002639.jpg
#   inflating: model/data/train/male/male_002640.jpg
#   inflating: model/data/train/male/male_002641.jpg
#   inflating: model/data/train/male/male_002642.jpg
#   inflating: model/data/train/male/male_002643.jpg
#   inflating: model/data/train/male/male_002644.jpg
#   inflating: model/data/train/male/male_002645.jpg
#   inflating: model/data/train/male/male_002646.jpg
#   inflating: model/data/train/male/male_002647.jpg
#   inflating: model/data/train/male/male_002648.jpg
#   inflating: model/data/train/male/male_002649.jpg
#   inflating: model/data/train/male/male_002650.jpg
#   inflating: model/data/train/male/male_002651.jpg
#   inflating: model/data/train/male/male_002652.jpg
#   inflating: model/data/train/male/male_002653.jpg
#   inflating: model/data/train/male/male_002654.jpg
#   inflating: model/data/train/male/male_002655.jpg
#   inflating: model/data/train/male/male_002656.jpg
#   inflating: model/data/train/male/male_002657.jpg
#   inflating: model/data/train/male/male_002658.jpg
#   inflating: model/data/train/male/male_002659.jpg
#   inflating: model/data/train/male/male_002660.jpg
#   inflating: model/data/train/male/male_002661.jpg
#   inflating: model/data/train/male/male_002662.jpg
#   inflating: model/data/train/male/male_002663.jpg
#   inflating: model/data/train/male/male_002664.jpg
#   inflating: model/data/train/male/male_002665.jpg
#   inflating: model/data/train/male/male_002666.jpg
#   inflating: model/data/train/male/male_002667.jpg
#   inflating: model/data/train/male/male_002668.jpg
#   inflating: model/data/train/male/male_002669.jpg
#   inflating: model/data/train/male/male_002670.jpg
#   inflating: model/data/train/male/male_002671.jpg
#   inflating: model/data/train/male/male_002672.jpg
#   inflating: model/data/train/male/male_002673.jpg
#   inflating: model/data/train/male/male_002674.jpg
#   inflating: model/data/train/male/male_002675.jpg
#   inflating: model/data/train/male/male_002676.jpg
#   inflating: model/data/train/male/male_002677.jpg
#   inflating: model/data/train/male/male_002678.jpg
#   inflating: model/data/train/male/male_002679.jpg
#   inflating: model/data/train/male/male_002680.jpg
#   inflating: model/data/train/male/male_002681.jpg
#   inflating: model/data/train/male/male_002682.jpg
#   inflating: model/data/train/male/male_002683.jpg
#   inflating: model/data/train/male/male_002684.jpg
#   inflating: model/data/train/male/male_002685.jpg
#   inflating: model/data/train/male/male_002686.jpg
#   inflating: model/data/train/male/male_002687.jpg
#   inflating: model/data/train/male/male_002688.jpg
#   inflating: model/data/train/male/male_002689.jpg
#   inflating: model/data/train/male/male_002690.jpg
#   inflating: model/data/train/male/male_002691.jpg
#   inflating: model/data/train/male/male_002692.jpg
#   inflating: model/data/train/male/male_002693.jpg
#   inflating: model/data/train/male/male_002694.jpg
#   inflating: model/data/train/male/male_002695.jpg
#   inflating: model/data/train/male/male_002696.jpg
#   inflating: model/data/train/male/male_002697.jpg
#   inflating: model/data/train/male/male_002698.jpg
#   inflating: model/data/train/male/male_002699.jpg
#   inflating: model/data/train/male/male_002700.jpg
#   inflating: model/data/train/male/male_002701.jpg
#   inflating: model/data/train/male/male_002702.jpg
#   inflating: model/data/train/male/male_002703.jpg
#   inflating: model/data/train/male/male_002704.jpg
#   inflating: model/data/train/male/male_002705.jpg
#   inflating: model/data/train/male/male_002706.jpg
#   inflating: model/data/train/male/male_002707.jpg
#   inflating: model/data/train/male/male_002708.jpg
#   inflating: model/data/train/male/male_002709.jpg
#   inflating: model/data/train/male/male_002710.jpg
#   inflating: model/data/train/male/male_002711.jpg
#   inflating: model/data/train/male/male_002712.jpg
#   inflating: model/data/train/male/male_002713.jpg
#   inflating: model/data/train/male/male_002714.jpg
#   inflating: model/data/train/male/male_002715.jpg
#   inflating: model/data/train/male/male_002716.jpg
#   inflating: model/data/train/male/male_002717.jpg
#   inflating: model/data/train/male/male_002718.jpg
#   inflating: model/data/train/male/male_002719.jpg
#   inflating: model/data/train/male/male_002720.jpg
#   inflating: model/data/train/male/male_002721.jpg
#   inflating: model/data/train/male/male_002722.jpg
#   inflating: model/data/train/male/male_002723.jpg
#   inflating: model/data/train/male/male_002724.jpg
#   inflating: model/data/train/male/male_002725.jpg
#   inflating: model/data/train/male/male_002726.jpg
#   inflating: model/data/train/male/male_002727.jpg
#   inflating: model/data/train/male/male_002728.jpg
#   inflating: model/data/train/male/male_002729.jpg
#   inflating: model/data/train/male/male_002730.jpg
#   inflating: model/data/train/male/male_002731.jpg
#   inflating: model/data/train/male/male_002732.jpg
#   inflating: model/data/train/male/male_002733.jpg
#   inflating: model/data/train/male/male_002734.jpg
#   inflating: model/data/train/male/male_002735.jpg
#   inflating: model/data/train/male/male_002736.jpg
#   inflating: model/data/train/male/male_002737.jpg
#   inflating: model/data/train/male/male_002738.jpg
#   inflating: model/data/train/male/male_002739.jpg
#   inflating: model/data/train/male/male_002740.jpg
#   inflating: model/data/train/male/male_002741.jpg
#   inflating: model/data/train/male/male_002742.jpg
#   inflating: model/data/train/male/male_002743.jpg
#   inflating: model/data/train/male/male_002744.jpg
#   inflating: model/data/train/male/male_002745.jpg
#   inflating: model/data/train/male/male_002746.jpg
#   inflating: model/data/train/male/male_002747.jpg
#   inflating: model/data/train/male/male_002748.jpg
#   inflating: model/data/train/male/male_002749.jpg
#   inflating: model/data/train/male/male_002750.jpg
#   inflating: model/data/train/male/male_002751.jpg
#   inflating: model/data/train/male/male_002752.jpg
#   inflating: model/data/train/male/male_002753.jpg
#   inflating: model/data/train/male/male_002754.jpg
#   inflating: model/data/train/male/male_002755.jpg
#   inflating: model/data/train/male/male_002756.jpg
#   inflating: model/data/train/male/male_002757.jpg
#   inflating: model/data/train/male/male_002758.jpg
#   inflating: model/data/train/male/male_002759.jpg
#   inflating: model/data/train/male/male_002760.jpg
#   inflating: model/data/train/male/male_002761.jpg
#   inflating: model/data/train/male/male_002762.jpg
#   inflating: model/data/train/male/male_002763.jpg
#   inflating: model/data/train/male/male_002764.jpg
#   inflating: model/data/train/male/male_002765.jpg
#   inflating: model/data/train/male/male_002766.jpg
#   inflating: model/data/train/male/male_002767.jpg
#   inflating: model/data/train/male/male_002768.jpg
#   inflating: model/data/train/male/male_002769.jpg
#   inflating: model/data/train/male/male_002770.jpg
#   inflating: model/data/train/male/male_002771.jpg
#   inflating: model/data/train/male/male_002772.jpg
#   inflating: model/data/train/male/male_002773.jpg
#   inflating: model/data/train/male/male_002774.jpg
#   inflating: model/data/train/male/male_002775.jpg
#   inflating: model/data/train/male/male_002776.jpg
#   inflating: model/data/train/male/male_002777.jpg
#   inflating: model/data/train/male/male_002778.jpg
#   inflating: model/data/train/male/male_002779.jpg
#   inflating: model/data/train/male/male_002780.jpg
#   inflating: model/data/train/male/male_002781.jpg
#   inflating: model/data/train/male/male_002782.jpg
#   inflating: model/data/train/male/male_002783.jpg
#   inflating: model/data/train/male/male_002784.jpg
#   inflating: model/data/train/male/male_002785.jpg
#   inflating: model/data/train/male/male_002786.jpg
#   inflating: model/data/train/male/male_002787.jpg
#   inflating: model/data/train/male/male_002788.jpg
#   inflating: model/data/train/male/male_002789.jpg
#   inflating: model/data/train/male/male_002790.jpg
#   inflating: model/data/train/male/male_002791.jpg
#   inflating: model/data/train/male/male_002792.jpg
#   inflating: model/data/train/male/male_002793.jpg
#   inflating: model/data/train/male/male_002794.jpg
#   inflating: model/data/train/male/male_002795.jpg
#   inflating: model/data/train/male/male_002796.jpg
#   inflating: model/data/train/male/male_002797.jpg
#   inflating: model/data/train/male/male_002798.jpg
#   inflating: model/data/train/male/male_002799.jpg
#   inflating: model/data/train/male/male_002800.jpg
#   inflating: model/data/train/male/male_002801.jpg
#   inflating: model/data/train/male/male_002802.jpg
#   inflating: model/data/train/male/male_002803.jpg
#   inflating: model/data/train/male/male_002804.jpg
#   inflating: model/data/train/male/male_002805.jpg
#   inflating: model/data/train/male/male_002806.jpg
#   inflating: model/data/train/male/male_002807.jpg
#   inflating: model/data/train/male/male_002808.jpg
#   inflating: model/data/train/male/male_002809.jpg
#   inflating: model/data/train/male/male_002810.jpg
#   inflating: model/data/train/male/male_002811.jpg
#   inflating: model/data/train/male/male_002812.jpg
#   inflating: model/data/train/male/male_002813.jpg
#   inflating: model/data/train/male/male_002814.jpg
#   inflating: model/data/train/male/male_002815.jpg
#   inflating: model/data/train/male/male_002816.jpg
#   inflating: model/data/train/male/male_002817.jpg
#   inflating: model/data/train/male/male_002818.jpg
#   inflating: model/data/train/male/male_002819.jpg
#   inflating: model/data/train/male/male_002820.jpg
#   inflating: model/data/train/male/male_002821.jpg
#   inflating: model/data/train/male/male_002822.jpg
#   inflating: model/data/train/male/male_002823.jpg
#   inflating: model/data/train/male/male_002824.jpg
#   inflating: model/data/train/male/male_002825.jpg
#   inflating: model/data/train/male/male_002826.jpg
#   inflating: model/data/train/male/male_002827.jpg
#   inflating: model/data/train/male/male_002828.jpg
#   inflating: model/data/train/male/male_002829.jpg
#   inflating: model/data/train/male/male_002830.jpg
#   inflating: model/data/train/male/male_002831.jpg
#   inflating: model/data/train/male/male_002832.jpg
#   inflating: model/data/train/male/male_002833.jpg
#   inflating: model/data/train/male/male_002834.jpg
#   inflating: model/data/train/male/male_002835.jpg
#   inflating: model/data/train/male/male_002836.jpg
#   inflating: model/data/train/male/male_002837.jpg
#   inflating: model/data/train/male/male_002838.jpg
#   inflating: model/data/train/male/male_002839.jpg
#   inflating: model/data/train/male/male_002840.jpg
#   inflating: model/data/train/male/male_002841.jpg
#   inflating: model/data/train/male/male_002842.jpg
#   inflating: model/data/train/male/male_002843.jpg
#   inflating: model/data/train/male/male_002844.jpg
#   inflating: model/data/train/male/male_002845.jpg
#   inflating: model/data/train/male/male_002846.jpg
#   inflating: model/data/train/male/male_002847.jpg
#   inflating: model/data/train/male/male_002848.jpg
#   inflating: model/data/train/male/male_002849.jpg
#   inflating: model/data/train/male/male_002850.jpg
#   inflating: model/data/train/male/male_002851.jpg
#   inflating: model/data/train/male/male_002852.jpg
#   inflating: model/data/train/male/male_002853.jpg
#   inflating: model/data/train/male/male_002854.jpg
#   inflating: model/data/train/male/male_002855.jpg
#   inflating: model/data/train/male/male_002856.jpg
#   inflating: model/data/train/male/male_002857.jpg
#   inflating: model/data/train/male/male_002858.jpg
#   inflating: model/data/train/male/male_002859.jpg
#   inflating: model/data/train/male/male_002860.jpg
#   inflating: model/data/train/male/male_002861.jpg
#   inflating: model/data/train/male/male_002862.jpg
#   inflating: model/data/train/male/male_002863.jpg
#   inflating: model/data/train/male/male_002864.jpg
#   inflating: model/data/train/male/male_002865.jpg
#   inflating: model/data/train/male/male_002866.jpg
#   inflating: model/data/train/male/male_002867.jpg
#   inflating: model/data/train/male/male_002868.jpg
#   inflating: model/data/train/male/male_002869.jpg
#   inflating: model/data/train/male/male_002870.jpg
#   inflating: model/data/train/male/male_002871.jpg
#   inflating: model/data/train/male/male_002872.jpg
#   inflating: model/data/train/male/male_002873.jpg
#   inflating: model/data/train/male/male_002874.jpg
#   inflating: model/data/train/male/male_002875.jpg
#   inflating: model/data/train/male/male_002876.jpg
#   inflating: model/data/train/male/male_002877.jpg
#   inflating: model/data/train/male/male_002878.jpg
#   inflating: model/data/train/male/male_002879.jpg
#   inflating: model/data/train/male/male_002880.jpg
#   inflating: model/data/train/male/male_002881.jpg
#   inflating: model/data/train/male/male_002882.jpg
#   inflating: model/data/train/male/male_002883.jpg
#   inflating: model/data/train/male/male_002884.jpg
#   inflating: model/data/train/male/male_002885.jpg
#   inflating: model/data/train/male/male_002886.jpg
#   inflating: model/data/train/male/male_002887.jpg
#   inflating: model/data/train/male/male_002888.jpg
#   inflating: model/data/train/male/male_002889.jpg
#   inflating: model/data/train/male/male_002890.jpg
#   inflating: model/data/train/male/male_002891.jpg
#   inflating: model/data/train/male/male_002892.jpg
#   inflating: model/data/train/male/male_002893.jpg
#   inflating: model/data/train/male/male_002894.jpg
#   inflating: model/data/train/male/male_002895.jpg
#   inflating: model/data/train/male/male_002896.jpg
#   inflating: model/data/train/male/male_002897.jpg
#   inflating: model/data/train/male/male_002898.jpg
#   inflating: model/data/train/male/male_002899.jpg
#   inflating: model/data/train/male/male_002900.jpg
#   inflating: model/data/train/male/male_002901.jpg
#   inflating: model/data/train/male/male_002902.jpg
#   inflating: model/data/train/male/male_002903.jpg
#   inflating: model/data/train/male/male_002904.jpg
#   inflating: model/data/train/male/male_002905.jpg
#   inflating: model/data/train/male/male_002906.jpg
#   inflating: model/data/train/male/male_002907.jpg
#   inflating: model/data/train/male/male_002908.jpg
#   inflating: model/data/train/male/male_002909.jpg
# ...
#   inflating: model/data/train/male/male_006705.jpg
#   inflating: model/data/train/male/male_006706.jpg
#   inflating: model/data/train/male/male_006707.jpg
#   inflating: model/data/train/male/male_006708.jpg
#   inflating: model/data/train/male/male_006709.jpg
#   inflating: model/data/train/male/male_006710.jpg
#   inflating: model/data/train/male/male_006711.jpg
#   inflating: model/data/train/male/male_006712.jpg
#   inflating: model/data/train/male/male_006713.jpg
#   inflating: model/data/train/male/male_006714.jpg
#   inflating: model/data/train/male/male_006715.jpg
#   inflating: model/data/train/male/male_006716.jpg
#   inflating: model/data/train/male/male_006717.jpg
#   inflating: model/data/train/male/male_006718.jpg
#   inflating: model/data/train/male/male_006719.jpg
#   inflating: model/data/train/male/male_006720.jpg
#   inflating: model/data/train/male/male_006721.jpg
#   inflating: model/data/train/male/male_006722.jpg
#   inflating: model/data/train/male/male_006723.jpg
#   inflating: model/data/train/male/male_006724.jpg
#   inflating: model/data/train/male/male_006725.jpg
#   inflating: model/data/train/male/male_006726.jpg
#   inflating: model/data/train/male/male_006727.jpg
#   inflating: model/data/train/male/male_006728.jpg
#   inflating: model/data/train/male/male_006729.jpg
#   inflating: model/data/train/male/male_006730.jpg
#   inflating: model/data/train/male/male_006731.jpg
#   inflating: model/data/train/male/male_006732.jpg
#   inflating: model/data/train/male/male_006733.jpg
#   inflating: model/data/train/male/male_006734.jpg
#   inflating: model/data/train/male/male_006735.jpg
#   inflating: model/data/train/male/male_006736.jpg
#   inflating: model/data/train/male/male_006737.jpg
#   inflating: model/data/train/male/male_006738.jpg
#   inflating: model/data/train/male/male_006739.jpg
#   inflating: model/data/train/male/male_006740.jpg
#   inflating: model/data/train/male/male_006741.jpg
#   inflating: model/data/train/male/male_006742.jpg
#   inflating: model/data/train/male/male_006743.jpg
#   inflating: model/data/train/male/male_006744.jpg
#   inflating: model/data/train/male/male_006745.jpg
#   inflating: model/data/train/male/male_006746.jpg
#   inflating: model/data/train/male/male_006747.jpg
#   inflating: model/data/train/male/male_006748.jpg
#   inflating: model/data/train/male/male_006749.jpg
#   inflating: model/data/train/male/male_006750.jpg
#   inflating: model/data/train/male/male_006751.jpg
#   inflating: model/data/train/male/male_006752.jpg
#   inflating: model/data/train/male/male_006753.jpg
#   inflating: model/data/train/male/male_006754.jpg
#   inflating: model/data/train/male/male_006755.jpg
#   inflating: model/data/train/male/male_006756.jpg
#   inflating: model/data/train/male/male_006757.jpg
#   inflating: model/data/train/male/male_006758.jpg
#   inflating: model/data/train/male/male_006759.jpg
#   inflating: model/data/train/male/male_006760.jpg
#   inflating: model/data/train/male/male_006761.jpg
#   inflating: model/data/train/male/male_006762.jpg
#   inflating: model/data/train/male/male_006763.jpg
#   inflating: model/data/train/male/male_006764.jpg
#   inflating: model/data/train/male/male_006765.jpg
#   inflating: model/data/train/male/male_006766.jpg
#   inflating: model/data/train/male/male_006767.jpg
#   inflating: model/data/train/male/male_006768.jpg
#   inflating: model/data/train/male/male_006769.jpg
#   inflating: model/data/train/male/male_006770.jpg
#   inflating: model/data/train/male/male_006771.jpg
#   inflating: model/data/train/male/male_006772.jpg
#   inflating: model/data/train/male/male_006773.jpg
#   inflating: model/data/train/male/male_006774.jpg
#   inflating: model/data/train/male/male_006775.jpg
#   inflating: model/data/train/male/male_006776.jpg
#   inflating: model/data/train/male/male_006777.jpg
#   inflating: model/data/train/male/male_006778.jpg
#   inflating: model/data/train/male/male_006779.jpg
#   inflating: model/data/train/male/male_006780.jpg
#   inflating: model/data/train/male/male_006781.jpg
#   inflating: model/data/train/male/male_006782.jpg
#   inflating: model/data/train/male/male_006783.jpg
#   inflating: model/data/train/male/male_006784.jpg
#   inflating: model/data/train/male/male_006785.jpg
#   inflating: model/data/train/male/male_006786.jpg
#   inflating: model/data/train/male/male_006787.jpg
#   inflating: model/data/train/male/male_006788.jpg
#   inflating: model/data/train/male/male_006789.jpg
#   inflating: model/data/train/male/male_006790.jpg
#   inflating: model/data/train/male/male_006791.jpg
#   inflating: model/data/train/male/male_006792.jpg
#   inflating: model/data/train/male/male_006793.jpg
#   inflating: model/data/train/male/male_006794.jpg
#   inflating: model/data/train/male/male_006795.jpg
#   inflating: model/data/train/male/male_006796.jpg
#   inflating: model/data/train/male/male_006797.jpg
#   inflating: model/data/train/male/male_006798.jpg
#   inflating: model/data/train/male/male_006799.jpg
#   inflating: model/data/train/male/male_006800.jpg
#   inflating: model/data/train/male/male_006801.jpg
#   inflating: model/data/train/male/male_006802.jpg
#   inflating: model/data/train/male/male_006803.jpg
#   inflating: model/data/train/male/male_006804.jpg
#   inflating: model/data/train/male/male_006805.jpg
#   inflating: model/data/train/male/male_006806.jpg
#   inflating: model/data/train/male/male_006807.jpg
#   inflating: model/data/train/male/male_006808.jpg
#   inflating: model/data/train/male/male_006809.jpg
#   inflating: model/data/train/male/male_006810.jpg
#   inflating: model/data/train/male/male_006811.jpg
#   inflating: model/data/train/male/male_006812.jpg
#   inflating: model/data/train/male/male_006813.jpg
#   inflating: model/data/train/male/male_006814.jpg
#   inflating: model/data/train/male/male_006815.jpg
#   inflating: model/data/train/male/male_006816.jpg
#   inflating: model/data/train/male/male_006817.jpg
#   inflating: model/data/train/male/male_006818.jpg
#   inflating: model/data/train/male/male_006819.jpg
#   inflating: model/data/train/male/male_006820.jpg
#   inflating: model/data/train/male/male_006821.jpg
#   inflating: model/data/train/male/male_006822.jpg
#   inflating: model/data/train/male/male_006823.jpg
#   inflating: model/data/train/male/male_006824.jpg
#   inflating: model/data/train/male/male_006825.jpg
#   inflating: model/data/train/male/male_006826.jpg
#   inflating: model/data/train/male/male_006827.jpg
#   inflating: model/data/train/male/male_006828.jpg
#   inflating: model/data/train/male/male_006829.jpg
#   inflating: model/data/train/male/male_006830.jpg
#   inflating: model/data/train/male/male_006831.jpg
#   inflating: model/data/train/male/male_006832.jpg
#   inflating: model/data/train/male/male_006833.jpg
#   inflating: model/data/train/male/male_006834.jpg
#   inflating: model/data/train/male/male_006835.jpg
#   inflating: model/data/train/male/male_006836.jpg
#   inflating: model/data/train/male/male_006837.jpg
#   inflating: model/data/train/male/male_006838.jpg
#   inflating: model/data/train/male/male_006839.jpg
#   inflating: model/data/train/male/male_006840.jpg
#   inflating: model/data/train/male/male_006841.jpg
#   inflating: model/data/train/male/male_006842.jpg
#   inflating: model/data/train/male/male_006843.jpg
#   inflating: model/data/train/male/male_006844.jpg
#   inflating: model/data/train/male/male_006845.jpg
#   inflating: model/data/train/male/male_006846.jpg
#   inflating: model/data/train/male/male_006847.jpg
#   inflating: model/data/train/male/male_006848.jpg
#   inflating: model/data/train/male/male_006849.jpg
#   inflating: model/data/train/male/male_006850.jpg
#   inflating: model/data/train/male/male_006851.jpg
#   inflating: model/data/train/male/male_006852.jpg
#   inflating: model/data/train/male/male_006853.jpg
#   inflating: model/data/train/male/male_006854.jpg
#   inflating: model/data/train/male/male_006855.jpg
#   inflating: model/data/train/male/male_006856.jpg
#   inflating: model/data/train/male/male_006857.jpg
#   inflating: model/data/train/male/male_006858.jpg
#   inflating: model/data/train/male/male_006859.jpg
#   inflating: model/data/train/male/male_006860.jpg
#   inflating: model/data/train/male/male_006861.jpg
#   inflating: model/data/train/male/male_006862.jpg
#   inflating: model/data/train/male/male_006863.jpg
#   inflating: model/data/train/male/male_006864.jpg
#   inflating: model/data/train/male/male_006865.jpg
#   inflating: model/data/train/male/male_006866.jpg
#   inflating: model/data/train/male/male_006867.jpg
#   inflating: model/data/train/male/male_006868.jpg
#   inflating: model/data/train/male/male_006869.jpg
#   inflating: model/data/train/male/male_006870.jpg
#   inflating: model/data/train/male/male_006871.jpg
#   inflating: model/data/train/male/male_006872.jpg
#   inflating: model/data/train/male/male_006873.jpg
#   inflating: model/data/train/male/male_006874.jpg
#   inflating: model/data/train/male/male_006875.jpg
#   inflating: model/data/train/male/male_006876.jpg
#   inflating: model/data/train/male/male_006877.jpg
#   inflating: model/data/train/male/male_006878.jpg
#   inflating: model/data/train/male/male_006879.jpg
#   inflating: model/data/train/male/male_006880.jpg
#   inflating: model/data/train/male/male_006881.jpg
#   inflating: model/data/train/male/male_006882.jpg
#   inflating: model/data/train/male/male_006883.jpg
#   inflating: model/data/train/male/male_006884.jpg
#   inflating: model/data/train/male/male_006885.jpg
#   inflating: model/data/train/male/male_006886.jpg
#   inflating: model/data/train/male/male_006887.jpg
#   inflating: model/data/train/male/male_006888.jpg
#   inflating: model/data/train/male/male_006889.jpg
#   inflating: model/data/train/male/male_006890.jpg
#   inflating: model/data/train/male/male_006891.jpg
#   inflating: model/data/train/male/male_006892.jpg
#   inflating: model/data/train/male/male_006893.jpg
#   inflating: model/data/train/male/male_006894.jpg
#   inflating: model/data/train/male/male_006895.jpg
#   inflating: model/data/train/male/male_006896.jpg
#   inflating: model/data/train/male/male_006897.jpg
#   inflating: model/data/train/male/male_006898.jpg
#   inflating: model/data/train/male/male_006899.jpg
#   inflating: model/data/train/male/male_006900.jpg
#   inflating: model/data/train/male/male_006901.jpg
#   inflating: model/data/train/male/male_006902.jpg
#   inflating: model/data/train/male/male_006903.jpg
#   inflating: model/data/train/male/male_006904.jpg
#   inflating: model/data/train/male/male_006905.jpg
#   inflating: model/data/train/male/male_006906.jpg
#   inflating: model/data/train/male/male_006907.jpg
#   inflating: model/data/train/male/male_006908.jpg
#   inflating: model/data/train/male/male_006909.jpg
#   inflating: model/data/train/male/male_006910.jpg
#   inflating: model/data/train/male/male_006911.jpg
#   inflating: model/data/train/male/male_006912.jpg
#   inflating: model/data/train/male/male_006913.jpg
#   inflating: model/data/train/male/male_006914.jpg
#   inflating: model/data/train/male/male_006915.jpg
#   inflating: model/data/train/male/male_006916.jpg
#   inflating: model/data/train/male/male_006917.jpg
#   inflating: model/data/train/male/male_006918.jpg
#   inflating: model/data/train/male/male_006919.jpg
#   inflating: model/data/train/male/male_006920.jpg
#   inflating: model/data/train/male/male_006921.jpg
#   inflating: model/data/train/male/male_006922.jpg
#   inflating: model/data/train/male/male_006923.jpg
#   inflating: model/data/train/male/male_006924.jpg
#   inflating: model/data/train/male/male_006925.jpg
#   inflating: model/data/train/male/male_006926.jpg
#   inflating: model/data/train/male/male_006927.jpg
#   inflating: model/data/train/male/male_006928.jpg
#   inflating: model/data/train/male/male_006929.jpg
#   inflating: model/data/train/male/male_006930.jpg
#   inflating: model/data/train/male/male_006931.jpg
#   inflating: model/data/train/male/male_006932.jpg
#   inflating: model/data/train/male/male_006933.jpg
#   inflating: model/data/train/male/male_006934.jpg
#   inflating: model/data/train/male/male_006935.jpg
#   inflating: model/data/train/male/male_006936.jpg
#   inflating: model/data/train/male/male_006937.jpg
#   inflating: model/data/train/male/male_006938.jpg
#   inflating: model/data/train/male/male_006939.jpg
#   inflating: model/data/train/male/male_006940.jpg
#   inflating: model/data/train/male/male_006941.jpg
#   inflating: model/data/train/male/male_006942.jpg
#   inflating: model/data/train/male/male_006943.jpg
#   inflating: model/data/train/male/male_006944.jpg
#   inflating: model/data/train/male/male_006945.jpg
#   inflating: model/data/train/male/male_006946.jpg
#   inflating: model/data/train/male/male_006947.jpg
#   inflating: model/data/train/male/male_006948.jpg
#   inflating: model/data/train/male/male_006949.jpg
#   inflating: model/data/train/male/male_006950.jpg
#   inflating: model/data/train/male/male_006951.jpg
#   inflating: model/data/train/male/male_006952.jpg
#   inflating: model/data/train/male/male_006953.jpg
#   inflating: model/data/train/male/male_006954.jpg
#   inflating: model/data/train/male/male_006955.jpg
#   inflating: model/data/train/male/male_006956.jpg
#   inflating: model/data/train/male/male_006957.jpg
#   inflating: model/data/train/male/male_006958.jpg
#   inflating: model/data/train/male/male_006959.jpg
#   inflating: model/data/train/male/male_006960.jpg
#   inflating: model/data/train/male/male_006961.jpg
#   inflating: model/data/train/male/male_006962.jpg
#   inflating: model/data/train/male/male_006963.jpg
#   inflating: model/data/train/male/male_006964.jpg
#   inflating: model/data/train/male/male_006965.jpg
#   inflating: model/data/train/male/male_006966.jpg
#   inflating: model/data/train/male/male_006967.jpg
#   inflating: model/data/train/male/male_006968.jpg
#   inflating: model/data/train/male/male_006969.jpg
#   inflating: model/data/train/male/male_006970.jpg
#   inflating: model/data/train/male/male_006971.jpg
#   inflating: model/data/train/male/male_006972.jpg
#   inflating: model/data/train/male/male_006973.jpg
#   inflating: model/data/train/male/male_006974.jpg
#   inflating: model/data/train/male/male_006975.jpg
#   inflating: model/data/train/male/male_006976.jpg
#   inflating: model/data/train/male/male_006977.jpg
#   inflating: model/data/train/male/male_006978.jpg
#   inflating: model/data/train/male/male_006979.jpg
#   inflating: model/data/train/male/male_006980.jpg
#   inflating: model/data/train/male/male_006981.jpg
#   inflating: model/data/train/male/male_006982.jpg
#   inflating: model/data/train/male/male_006983.jpg
#   inflating: model/data/train/male/male_006984.jpg
#   inflating: model/data/train/male/male_006985.jpg
#   inflating: model/data/train/male/male_006986.jpg
#   inflating: model/data/train/male/male_006987.jpg
#   inflating: model/data/train/male/male_006988.jpg
#   inflating: model/data/train/male/male_006989.jpg
#   inflating: model/data/train/male/male_006990.jpg
#   inflating: model/data/train/male/male_006991.jpg
#   inflating: model/data/train/male/male_006992.jpg
#   inflating: model/data/train/male/male_006993.jpg
#   inflating: model/data/train/male/male_006994.jpg
#   inflating: model/data/train/male/male_006995.jpg
#   inflating: model/data/train/male/male_006996.jpg
#   inflating: model/data/train/male/male_006997.jpg
#   inflating: model/data/train/male/male_006998.jpg
#   inflating: model/data/train/male/male_006999.jpg
#   inflating: model/Gender Classification using Deep learning.ipynb
#   inflating: model/Gender_classification.py
#   inflating: model/Gender_classification_grayScale.ipynb
#   inflating: model/Gender_classification_using_NN model.ipynb
#   inflating: model/Usefull_codes & Pretrained models.ipynb
#   inflating: model/video.mp4

# %% [markdown]
# 2) The second method is the following:
#
# First you install and import libraries
#
# ```
# !pip install -U -q PyDrive
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials
# ```
#
# Then you authenticate yourself and connect to Google Drive
#
#
# ```
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)
# ```
# Then you download the file your_data.zip from Google Drive to Colab:
#
# ```
# fid = drive.ListFile({'q':"title='your_data.zip'"}).GetList()[0]['id']
# f = drive.CreateFile({'id': fid})
# f.GetContentFile('your_data.zip')
# ```
#
# **From here you can unzip them and do whatever training you need.**

# %% [markdown]
# ### 1) Import the libraries

# %%
# Update the tensorflow
# !pip install --upgrade tensorflow

# The tensorflow version in this project is : 3.7.0

# %%
# import libraries 
import os
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(tf.__version__)
print("Done!")
# Out:
# 2.7.0
# Done!

# %% [markdown]
# ### 2) Load the dataset from directories

# %%
###### 1) Upload dataset from directories
DATADIR = "model/data/train/"
CATEGORIES = ['female', 'male']

IMG_SIZE = 150
batch_size= 32 # Others batch sizes 64, 128, and 256.

ds_train_ = tf.keras.preprocessing.image_dataset_from_directory(DATADIR,
    labels="inferred",
    label_mode = "binary", # int or categorical
    #class_names = CATEGORIES,
    #color_mode ="grayscale", # Uncomment thi to wirk in the gray scale
    batch_size = batch_size,
    image_size = (IMG_SIZE,IMG_SIZE), # reshape if not in this size
    shuffle = True,
    seed= 123, # to maintain the same data when spliyying the data
    validation_split = 0.2,
    subset = "training",
)


ds_valid_ = tf.keras.preprocessing.image_dataset_from_directory(DATADIR,
    labels="inferred",
    label_mode = "binary", # Other label modes are: int or categorical
    #class_names = CATEGORIES,
    #color_mode ="grayscale", # Uncomment thi to wirk in the gray scale
    batch_size = batch_size,
    image_size = (IMG_SIZE,IMG_SIZE), # reshape if not in this size
    shuffle = True,
    seed= 123, # to maintain the same results for different runs and data when splitting the data 
    validation_split = 0.2,
    subset = "validation",
)

print("Done!")
# Out:
# Found 14000 files belonging to 2 classes.
# Using 11200 files for training.
# Found 14000 files belonging to 2 classes.
# Using 2800 files for validation.
# Done!

# %%
class_names = ds_train_.class_names
class_names
# Out:
# ['female', 'male']

# %%
#images, labels = ds_train_.take(2)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
for images, labels in ds_train_.take(2):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[int(labels[i])])
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ### 3) Preprocess the data and create Checkpoints
#
# ###### Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# + **Dataset.cache** keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# + **Dataset.prefetch** overlaps data preprocessing and model execution while training.
#
# > ***For more details, please visit***  [Tensorflow tutorials: classificattion](https://www.tensorflow.org/tutorials/images/classification)

# %%
# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

#def standardize(image_data):
        #image_data -= np.mean(image_data, axis=0)
        #image_data /= np.std(image_data, axis=0)
       # return image_data

AUTOTUNE = tf.data.experimental.AUTOTUNE # Search for this 
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# save checkpoints during training

checkpoint_path = "/content/model/Pretrained model/checkpoints_training/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

print("Done!")
# Out:
# Done!

# %% [markdown]
# ### 4) Create the model
#
# The Sequential model consists of three basic convolution blocks (tf.keras.layers.Conv2D) with a max pooling layer (tf.keras.layers.MaxPooling2D) in each of them (the base) followed by a head of Dense layers. There's a fully-connected layer (tf.keras.layers.Dense) with 128 units on top of it that is activated by a ReLU activation function ('relu').
#
# > *NP: This model has not been tuned for high accuracy.*

# %%
IMG_SIZE = 150
batch_size= 32 # Others batch sizes 64, 128, and 256.

model = keras.Sequential([
    # Rescaling the images to [0,1]
    layers.Rescaling(1./255, input_shape=[IMG_SIZE,IMG_SIZE, 3]),
    # First Convolutional Block
    layers.Conv2D(filters=32, kernel_size=5, activation="relu", padding='same'
                  # give the input dimensions in the first layer
                  # [height, width, color channels(RGB)]
                  ), # Please recheck the number of channels in your input images
    layers.MaxPool2D(),

    # Second Convolutional Block
    layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding='same'),
    layers.MaxPool2D(),

    # Third Convolutional Block
    layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding='same'),
    layers.MaxPool2D(),

    # Classifier Head
    layers.Flatten(),
    layers.Dense(units=128, activation="relu"),
    layers.Dense(units=1, activation="sigmoid"),
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 32)      2432
#
#  max_pooling2d_9 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 90, 90, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 45, 45, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 45, 45, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 22, 22, 128)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 61952)             0
#
#  dense_6 (Dense)             (None, 128)               7929984
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,024,897
# Trainable params: 8,024,897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5) Compile the model
#
# I choosed the tf.keras.optimizers.Adam optimizer and binary_crossentropy loss function. To view training and validation accuracy for each training epoch, pass the metrics argument to Model.compile.

# %%
# Compile and fit the model
#learning_rate=0.001 
optimizer = tf.keras.optimizers.Adam()#learning_rate= 0.05, epsilon=0.01)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

print("Done!")
# Out:
# Done!

# %% [markdown]
# ### 6) train the model

# %%
batch_size = 30
epochs = 11 # then use 25 and 50

history = model.fit(
    ds_train,
    validation_data=ds_valid,
    batch_size= batch_size,  # Others batch sizes 64, 128, and 256.
    epochs=epochs,
    callbacks=[cp_callback]  # Pass callback to training
)

print("Congratualation the model learned!")
# Out:
# Epoch 1/11
# 350/350 [==============================] - ETA: 0s - loss: 0.6402 - binary_accuracy: 0.6406
# Epoch 00001: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 842s 2s/step - loss: 0.6402 - binary_accuracy: 0.6406 - val_loss: 0.5753 - val_binary_accuracy: 0.7029
# Epoch 2/11
# 350/350 [==============================] - ETA: 0s - loss: 0.5528 - binary_accuracy: 0.7231
# Epoch 00002: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 823s 2s/step - loss: 0.5528 - binary_accuracy: 0.7231 - val_loss: 0.5587 - val_binary_accuracy: 0.7271
# Epoch 3/11
# 350/350 [==============================] - ETA: 0s - loss: 0.5017 - binary_accuracy: 0.7570
# Epoch 00003: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 822s 2s/step - loss: 0.5017 - binary_accuracy: 0.7570 - val_loss: 0.5322 - val_binary_accuracy: 0.7464
# Epoch 4/11
# 350/350 [==============================] - ETA: 0s - loss: 0.4461 - binary_accuracy: 0.7858
# Epoch 00004: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 820s 2s/step - loss: 0.4461 - binary_accuracy: 0.7858 - val_loss: 0.5044 - val_binary_accuracy: 0.7629
# Epoch 5/11
# 350/350 [==============================] - ETA: 0s - loss: 0.3779 - binary_accuracy: 0.8263
# Epoch 00005: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 823s 2s/step - loss: 0.3779 - binary_accuracy: 0.8263 - val_loss: 0.5252 - val_binary_accuracy: 0.7775
# Epoch 6/11
# 350/350 [==============================] - ETA: 0s - loss: 0.3119 - binary_accuracy: 0.8583
# Epoch 00006: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 818s 2s/step - loss: 0.3119 - binary_accuracy: 0.8583 - val_loss: 0.5644 - val_binary_accuracy: 0.7746
# Epoch 7/11
# 350/350 [==============================] - ETA: 0s - loss: 0.2624 - binary_accuracy: 0.8815
# Epoch 00007: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 821s 2s/step - loss: 0.2624 - binary_accuracy: 0.8815 - val_loss: 0.6140 - val_binary_accuracy: 0.7775
# Epoch 8/11
# 350/350 [==============================] - ETA: 0s - loss: 0.2208 - binary_accuracy: 0.8988
# Epoch 00008: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 824s 2s/step - loss: 0.2208 - binary_accuracy: 0.8988 - val_loss: 0.7294 - val_binary_accuracy: 0.7632
# Epoch 9/11
# 350/350 [==============================] - ETA: 0s - loss: 0.1930 - binary_accuracy: 0.9157
# Epoch 00009: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 822s 2s/step - loss: 0.1930 - binary_accuracy: 0.9157 - val_loss: 0.6836 - val_binary_accuracy: 0.7804
# Epoch 10/11
# 350/350 [==============================] - ETA: 0s - loss: 0.1740 - binary_accuracy: 0.9217
# Epoch 00010: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 820s 2s/step - loss: 0.1740 - binary_accuracy: 0.9217 - val_loss: 0.7561 - val_binary_accuracy: 0.7843
# Epoch 11/11
# 350/350 [==============================] - ETA: 0s - loss: 0.1439 - binary_accuracy: 0.9404
# Epoch 00011: saving model to /content/model/Pretrained model/checkpoints_training/cp.ckpt
# 350/350 [==============================] - 820s 2s/step - loss: 0.1439 - binary_accuracy: 0.9404 - val_loss: 0.8600 - val_binary_accuracy: 0.7800
# Congratualation the model learned!

# %% [markdown]
# ### 7) Plot learning curves

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# ### 8) Creating the model with data augmetaion:
#
#
#
# ```
# # Model with data augumentation
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     layers.InputLayer(input_shape=[128, 128, 3]),
#
#     # Data Augmentation
#     preprocessing.RandomContrast(factor=0.10),
#     preprocessing.RandomFlip(mode='horizontal'),
#     preprocessing.RandomRotation(factor=0.10),
#
#     #preprocessing.RandomContrast(factor=0.3),
#    # preprocessing.RandomFlip(mode='horizontal'), # meaning, left-to-right
#     #preprocessing.RandomFlip(mode='vertical'), # meaning, top-to-bottom
#     #preprocessing.RandomWidth(factor=0.15), # horizontal stretch
#    # preprocessing.RandomRotation(factor=0.20),
#     #preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
#
#     # Block One
#     layers.BatchNormalization(renorm=True),
#     layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Two
#     layers.BatchNormalization(renorm=True),
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Three
#     layers.BatchNormalization(renorm=True),
#     layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
#     layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Head
#     layers.BatchNormalization(renorm=True),
#     layers.Flatten(),
#     layers.Dense(8, activation='relu'),
#     layers.Dense(1, activation='sigmoid'),
# ])
#
#
# # Compile and fit the model
# optimizer = tf.keras.optimizers.Adam(epsilon=0.01)
# model.compile(
#     optimizer=optimizer,
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# history = model.fit(
#     ds_train,
#     validation_data=ds_valid,
#     epochs=50,
# )
#
# # Plot learning curves
# import pandas as pd
# history_frame = pd.DataFrame(history.history)
# history_frame.loc[:, ['loss', 'val_loss']].plot()
# history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();
# ```

# %%
# Second Model:

# Model with data augumentation

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing


batch_size = 30
epochs = 11 # then use 25 and 50 (Due to the lake of the computational power I used 11. If you have it, Use 50 epochs which is better for this model)

model2 = keras.Sequential([
    layers.InputLayer(input_shape=[IMG_SIZE, IMG_SIZE, 3]),
    layers.Rescaling(1./255),
    # Data Augmentation
    preprocessing.RandomContrast(factor=0.10),
    preprocessing.RandomFlip(mode='horizontal'),
    preprocessing.RandomRotation(factor=0.10),

    #preprocessing.RandomContrast(factor=0.3),
   # preprocessing.RandomFlip(mode='horizontal'), # meaning, left-to-right
    #preprocessing.RandomFlip(mode='vertical'), # meaning, top-to-bottom
    #preprocessing.RandomWidth(factor=0.15), # horizontal stretch
   # preprocessing.RandomRotation(factor=0.20),
    preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),

    # Block One
    layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Two
    layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.BatchNormalization(renorm=True),
    layers.Flatten(),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])


# Compile and fit the model 
optimizer2 = tf.keras.optimizers.Adam(epsilon=0.01)
model2.compile(
    optimizer=optimizer2,
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

history2 = model2.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=epochs,
)

print("Done!")
# Out:
# Epoch 1/11
# 350/350 [==============================] - 1962s 6s/step - loss: 0.7085 - binary_accuracy: 0.5314 - val_loss: 0.7382 - val_binary_accuracy: 0.5021
# Epoch 2/11
# 350/350 [==============================] - 1913s 5s/step - loss: 0.7043 - binary_accuracy: 0.5984 - val_loss: 0.6297 - val_binary_accuracy: 0.6704
# Epoch 3/11
# 350/350 [==============================] - 1901s 5s/step - loss: 0.7871 - binary_accuracy: 0.6315 - val_loss: 0.6295 - val_binary_accuracy: 0.6807
# Epoch 4/11
# 350/350 [==============================] - 1892s 5s/step - loss: 0.6233 - binary_accuracy: 0.6617 - val_loss: 0.6016 - val_binary_accuracy: 0.6904
# Epoch 5/11
# 350/350 [==============================] - 1884s 5s/step - loss: 0.6078 - binary_accuracy: 0.6752 - val_loss: 0.6504 - val_binary_accuracy: 0.6164
# Epoch 6/11
# 350/350 [==============================] - 1871s 5s/step - loss: 0.5918 - binary_accuracy: 0.6889 - val_loss: 0.5583 - val_binary_accuracy: 0.7332
# Epoch 7/11
# 350/350 [==============================] - 1867s 5s/step - loss: 0.5808 - binary_accuracy: 0.6995 - val_loss: 0.5442 - val_binary_accuracy: 0.7300
# Epoch 8/11
# 350/350 [==============================] - 1890s 5s/step - loss: 0.5663 - binary_accuracy: 0.7131 - val_loss: 0.5359 - val_binary_accuracy: 0.7454
# Epoch 9/11
# 350/350 [==============================] - 1940s 6s/step - loss: 0.5589 - binary_accuracy: 0.7180 - val_loss: 0.5289 - val_binary_accuracy: 0.7443
# Epoch 10/11
# 350/350 [==============================] - 1972s 6s/step - loss: 0.5558 - binary_accuracy: 0.7237 - val_loss: 0.5148 - val_binary_accuracy: 0.7629
# Epoch 11/11
# 350/350 [==============================] - 1901s 5s/step - loss: 0.5460 - binary_accuracy: 0.7265 - val_loss: 0.5090 - val_binary_accuracy: 0.7671
# Done!

# %%
# Plot learning curves
import pandas as pd
history_frame2 = pd.DataFrame(history2.history)
history_frame2.loc[:, ['loss', 'val_loss']].plot()
history_frame2.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %%
# Another way to visualize the trainning accuracy 
acc = history2.history['binary_accuracy']
val_acc = history2.history['val_binary_accuracy']

loss = history2.history['loss']
val_loss = history2.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(14, 14))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### 9) Save and load the trained model
#
# Setup
# Install and import TensorFlow and dependencies:
#
#
# ```
# pip install pyyaml h5py  # Required to save models in HDF5 format
#
# ```
#
#
#
# > Model progress can be saved during and after training.

# %%
# Installs and imports libraries:
# !pip install pyyaml h5py
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)

# %%
#from tensorflow import keras

dir_pretrainedModel = "/model/Pretrained_model"
#dir_pretrainedModel = "/content/model/Pretrained model"
filename = dir_pretrainedModel + '/' +  'my_model2.h5'
# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
model2.save(filename)


# Recreate the exact same model, including its weights and the optimizer
new_model2 = tf.keras.models.load_model(filename)

new_model2

# %% [markdown]
# ### 10) Prediction
#
# Import new image to test the performance of the proposed model:

# %%
Gender_url = "./model/data/test/male_000281.jpg"
#Gender_path = tf.keras.utils.get_file(Gender_url)

img = tf.keras.utils.load_img(
    Gender_url, target_size=(IMG_SIZE, IMG_SIZE)
)

img_array= tf.keras.utils.img_to_array(img)
img_array= tf.expand_dims(img_array,0) #create patch (I have just one
img_array = img_array/255
predictions= new_model2.predict(img_array)
#pred_accuracy = predictions
score = tf.nn.softmax(predictions[0])

print("The image is likely belong to {} with a {:.2f}% percent confidence.".format(class_names[int(score)], 100*float(predictions)))
# Out:
# The image is likely belong to male with a 71.75% percent confidence.

# %%
IMG_SIZE = 280

Gender_url = "./data/test/male_000281.jpg"
#Gender_path = tf.keras.utils.get_file(Gender_url)

img = tf.keras.utils.load_img(
    Gender_url, target_size=(IMG_SIZE, IMG_SIZE)
)

type(img)
# Out:
# PIL.Image.Image

# %%
import cv2
# load haar cascade classifier
haar = cv2.CascadeClassifier('./Pretrained_model/haarcascade_frontalface_default.xml')

# %%
# summarize some details about the image
print(img.format)
print(img.mode)
print(img.size)
# show the image
img.show()
# Out:
# None
# RGB
# (250, 250)

# %%
import numpy as np
from numpy import asarray
open_cv_image = np.array(img)

# %%
gray = cv2.cvtColor(open_cv_image,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (280, 280)

# %%
import cv2

#img_data = asarray(img)
faces = haar.detectMultiScale(gray,1.5,5)
print(faces)
# Out:
# [[ 68  37 182 182]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for x,y,w,h in faces:
    cv2.rectangle(gray, (0, int(IMG_SIZE)), (int(img.size[1]), int(IMG_SIZE)), (0, 255, 0), 5)
    #cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(gray)

# %%
# step -10:
predict = results.argmax() # 0 or 1 
score = results[predict]
# step -11:
text = "%s : %0.2f"%(gender_pre[predict],score)
cv2.putText(img,text,(x,y),font,1,(255,255,0),2)

# %%
dir_pretrainedModel = "./Pretrained_model/my_model2.h5"
# Recreate the exact same model, including its weights and the optimizer
new_model2 = tf.keras.models.load_model(dir_pretrainedModel)

new_model2
